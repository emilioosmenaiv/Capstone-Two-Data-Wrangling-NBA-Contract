# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
stats = pd.read_csv('BOOKER.CSV')

# %%
stats
# Out:
#      Season  Age  Player   Lg  Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0   2015-16   19  Booker  NBA   SG  76  51  27.7  4.8  11.4  ...  .840  0.4
# 1   2016-17   20  Booker  NBA   SG  78  78  35.0  7.8  18.3  ...  .832  0.6
# 2   2017-18   21  Booker  NBA   SG  54  54  34.5  8.4  19.5  ...  .878  0.5
# 3   2018-19   22  Booker  NBA   SG  64  64  35.0  9.2  19.6  ...  .866  0.6
# 4   2019-20   23  Booker  NBA   SG  70  70  35.9  9.0  18.3  ...  .919  0.4
# ..      ...  ...     ...  ...  ...  ..  ..   ...  ...   ...  ...   ...  ...
# 65   Season  Age  PLAYER   Lg  Pos   G  GS    MP   FG   FGA  ...   FT%  ORB
# 66  2018-19   19  Doncic  NBA   SG  72  72  32.2  7.0  16.5  ...  .713  1.2
# 67  2019-20   20  Doncic  NBA   PG  61  61  33.6  9.5  20.6  ...  .758  1.3
# 68  2020-21   21  Doncic  NBA   PG  66  66  34.3  9.8  20.5  ...  .730  0.8
# 69  2021-22   22  Doncic  NBA   PG  65  65  35.4  9.9  21.6  ...  .744  0.9
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
missing = pd.concat([stats.isnull().sum(), 100 * stats.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#         count    %
# Season      0  0.0
# TOV         0  0.0
# BLK         0  0.0
# STL         0  0.0
# AST         0  0.0
# TRB         0  0.0
# DRB         0  0.0
# ORB         0  0.0
# FT%         0  0.0
# FTA         0  0.0
# FT          0  0.0
# eFG%        0  0.0
# 2P%         0  0.0
# 2PA         0  0.0
# 2P          0  0.0
# 3P%         0  0.0
# 3PA         0  0.0
# 3P          0  0.0
# FG%         0  0.0
# FGA         0  0.0
# FG          0  0.0
# MP          0  0.0
# GS          0  0.0
# G           0  0.0
# Pos         0  0.0
# Lg          0  0.0
# Player      0  0.0
# Age         0  0.0
# PF          0  0.0
# PTS         0  0.0

# %%
stats.dtypes
# Out:
# Season    object
# Age       object
# Player    object
# Lg        object
# Pos       object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
stats['Player'].value_counts()
# Out:
# Harden                            17
# Westbrook                         14
# Curry                             13
# Thompson                           9
# Booker                             7
# PLAYER                             4
# Doncic                             4
# Did Not Play (injury—knee)         1
# Did Not Play (injury—achilles)     1
# Name: Player, dtype: int64

# %%
stats['PTS'].unique()
# Out:
# array(['13.8', '22.1', '24.9', '26.6', '25.6', '26.8', '17.5', '18.6',
#        '14.7', '22.9', '24.0', '23.8', '30.1', '25.3', '26.4', '27.3',
#        '20.8', '32.0', '25.5', 'PTS', '12.5', '16.6', '18.4', '21.7',
#        '22.3', '20.0', '21.5', 'Did Not Play (injury—knee)',
#        'Did Not Play (injury—achilles)', '20.4', '9.9', '12.2', '16.8',
#        '25.9', '25.4', '27.4', '29.0', '29.1', '30.4', '36.1', '34.3',
#        '24.6', '24.8', '22.0', '22.5', '21.0', '15.3', '16.1', '21.9',
#        '23.6', '23.2', '21.8', '28.1', '23.5', '31.6', '27.2', '22.2',
#        '18.5', '21.2', '28.8', '27.7', '28.4'], dtype=object)

# %%
stats[stats.Player=="PLAYER"]
# Out:
#     Season  Age  Player  Lg  Pos  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 20  Season  Age  PLAYER  Lg  Pos  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 32  Season  Age  PLAYER  Lg  Pos  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 50  Season  Age  PLAYER  Lg  Pos  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 65  Season  Age  PLAYER  Lg  Pos  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
#
#     AST  STL  BLK  TOV  PF  PTS
# 20  AST  STL  BLK  TOV  PF  PTS
# 32  AST  STL  BLK  TOV  PF  PTS
# 50  AST  STL  BLK  TOV  PF  PTS
# 65  AST  STL  BLK  TOV  PF  PTS
#
# [4 rows x 30 columns]

# %%
stats[stats.Player=="Did Not Play (injury—knee)"]
# Out:
#      Season Age                      Player                          Lg  \
# 29  2019-20  29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                            Pos                           G  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                             GS                          MP  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                             FG                         FGA  ...  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)  ...
#
#                            FT%                         ORB  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                            DRB                         TRB  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                            AST                         STL  \
# 29  Did Not Play (injury—knee)  Did Not Play (injury—knee)
#
#                            BLK                         TOV  \
# ...

# %%
stats[stats.Player=="Did Not Play (injury—achilles)"]
# Out:
#      Season Age                          Player  \
# 30  2020-21  30  Did Not Play (injury—achilles)
#
#                                 Lg                             Pos  \
# 30  Did Not Play (injury—achilles)  Did Not Play (injury—achilles)
#
#                                  G                              GS  \
# 30  Did Not Play (injury—achilles)  Did Not Play (injury—achilles)
#
#                                 MP                              FG  \
# 30  Did Not Play (injury—achilles)  Did Not Play (injury—achilles)
#
#                                FGA  ...                             FT%  \
# 30  Did Not Play (injury—achilles)  ...  Did Not Play (injury—achilles)
#
#                                ORB                             DRB  \
# 30  Did Not Play (injury—achilles)  Did Not Play (injury—achilles)
#
#                                TRB                             AST  \
# 30  Did Not Play (injury—achilles)  Did Not Play (injury—achilles)
#
# ...

# %%
stats_clean=stats.drop(stats.index[[20,29,30,32,50,65]])
stats_clean
# Out:
#      Season Age     Player   Lg Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 0   2015-16  19     Booker  NBA  SG  76  51  27.7  4.8  11.4  ...  .840  0.4
# 1   2016-17  20     Booker  NBA  SG  78  78  35.0  7.8  18.3  ...  .832  0.6
# 2   2017-18  21     Booker  NBA  SG  54  54  34.5  8.4  19.5  ...  .878  0.5
# 3   2018-19  22     Booker  NBA  SG  64  64  35.0  9.2  19.6  ...  .866  0.6
# 4   2019-20  23     Booker  NBA  SG  70  70  35.9  9.0  18.3  ...  .919  0.4
# ..      ...  ..        ...  ...  ..  ..  ..   ...  ...   ...  ...   ...  ...
# 64  2021-22  33  Westbrook  NBA  PG  78  78  34.3  7.0  15.8  ...  .667  1.4
# 66  2018-19  19     Doncic  NBA  SG  72  72  32.2  7.0  16.5  ...  .713  1.2
# 67  2019-20  20     Doncic  NBA  PG  61  61  33.6  9.5  20.6  ...  .758  1.3
# 68  2020-21  21     Doncic  NBA  PG  66  66  34.3  9.8  20.5  ...  .730  0.8
# 69  2021-22  22     Doncic  NBA  PG  65  65  35.4  9.9  21.6  ...  .744  0.9
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# ...

# %%
stats_clean['Player'].value_counts()
# Out:
# Harden       17
# Westbrook    14
# Curry        13
# Thompson      9
# Booker        7
# Doncic        4
# Name: Player, dtype: int64

# %%
booker=stats[stats.Player=="Booker"]
booker
# Out:
#     Season Age  Player   Lg Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  DRB  \
# 0  2015-16  19  Booker  NBA  SG  76  51  27.7  4.8  11.4  ...  .840  0.4  2.1
# 1  2016-17  20  Booker  NBA  SG  78  78  35.0  7.8  18.3  ...  .832  0.6  2.6
# 2  2017-18  21  Booker  NBA  SG  54  54  34.5  8.4  19.5  ...  .878  0.5  4.0
# 3  2018-19  22  Booker  NBA  SG  64  64  35.0  9.2  19.6  ...  .866  0.6  3.5
# 4  2019-20  23  Booker  NBA  SG  70  70  35.9  9.0  18.3  ...  .919  0.4  3.8
# 5  2020-21  24  Booker  NBA  SG  67  67  33.9  9.3  19.2  ...  .867  0.5  3.7
# 6  2021-22  25  Booker  NBA  SG  68  68  34.5  9.7  20.9  ...  .868  0.7  4.4
#
#    TRB  AST  STL  BLK  TOV   PF   PTS
# 0  2.5  2.6  0.6  0.3  2.1  3.0  13.8
# 1  3.2  3.4  0.9  0.3  3.1  3.1  22.1
# 2  4.5  4.7  0.9  0.3  3.6  3.1  24.9
# 3  4.1  6.8  0.9  0.2  4.1  3.1  26.6
# 4  4.2  6.5  0.7  0.3  3.8  3.0  26.6
# 5  4.2  4.3  0.8  0.2  3.1  2.7  25.6
# 6  5.0  4.8  1.1  0.4  2.4  2.6  26.8
#
# [7 rows x 30 columns]

# %%
stats_clean[stats_clean.Player=="Doncic"]
# Out:
#      Season Age  Player   Lg Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 66  2018-19  19  Doncic  NBA  SG  72  72  32.2  7.0  16.5  ...  .713  1.2
# 67  2019-20  20  Doncic  NBA  PG  61  61  33.6  9.5  20.6  ...  .758  1.3
# 68  2020-21  21  Doncic  NBA  PG  66  66  34.3  9.8  20.5  ...  .730  0.8
# 69  2021-22  22  Doncic  NBA  PG  65  65  35.4  9.9  21.6  ...  .744  0.9
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 66  6.6  7.8  6.0  1.1  0.3  3.4  1.9  21.2
# 67  8.1  9.4  8.8  1.0  0.2  4.3  2.5  28.8
# 68  7.2  8.0  8.6  1.0  0.5  4.3  2.3  27.7
# 69  8.3  9.1  8.7  1.2  0.6  4.5  2.2  28.4
#
# [4 rows x 30 columns]

# %%
stats_clean[stats_clean.Player=="Harden"]
# Out:
#      Season Age  Player   Lg   Pos   G  GS    MP    FG   FGA  ...   FT%  ORB  \
# 33  2009-10  20  Harden  NBA    SG  76   0  22.9   3.1   7.6  ...  .808  0.6
# 34  2010-11  21  Harden  NBA    SG  82   5  26.7   3.6   8.3  ...  .843  0.5
# 35  2011-12  22  Harden  NBA    SG  62   2  31.4   5.0  10.1  ...  .846  0.5
# 36  2012-13  23  Harden  NBA    SG  78  78  38.3   7.5  17.1  ...  .851  0.8
# 37  2013-14  24  Harden  NBA    SG  73  73  38.0   7.5  16.5  ...  .866  0.8
# 38  2014-15  25  Harden  NBA    SG  81  81  36.8   8.0  18.1  ...  .868  0.9
# 39  2015-16  26  Harden  NBA    SG  82  82  38.1   8.7  19.7  ...  .860  0.8
# 40  2016-17  27  Harden  NBA    PG  81  81  36.4   8.3  18.9  ...  .847  1.2
# 41  2017-18  28  Harden  NBA    SG  72  72  35.4   9.0  20.1  ...  .858  0.6
# 42  2018-19  29  Harden  NBA    PG  78  78  36.8  10.8  24.5  ...  .879  0.8
# 43  2019-20  30  Harden  NBA    SG  68  68  36.5   9.9  22.3  ...  .865  1.0
# ...

# %%
stats_clean[stats_clean.Player=="Westbrook"]
# Out:
#      Season Age     Player   Lg Pos   G  GS    MP    FG   FGA  ...   FT%  ORB  \
# 51  2008-09  20  Westbrook  NBA  PG  82  65  32.5   5.3  13.4  ...  .815  2.2
# 52  2009-10  21  Westbrook  NBA  PG  82  82  34.3   5.9  14.1  ...  .780  1.7
# 53  2010-11  22  Westbrook  NBA  PG  82  82  34.7   7.5  17.0  ...  .842  1.5
# 54  2011-12  23  Westbrook  NBA  PG  66  66  35.3   8.8  19.2  ...  .823  1.5
# 55  2012-13  24  Westbrook  NBA  PG  82  82  34.9   8.2  18.7  ...  .800  1.4
# 56  2013-14  25  Westbrook  NBA  PG  46  46  30.7   7.5  17.2  ...  .826  1.2
# 57  2014-15  26  Westbrook  NBA  PG  67  67  34.4   9.4  22.0  ...  .835  1.9
# 58  2015-16  27  Westbrook  NBA  PG  80  80  34.4   8.2  18.1  ...  .812  1.8
# 59  2016-17  28  Westbrook  NBA  PG  81  81  34.6  10.2  24.0  ...  .845  1.7
# 60  2017-18  29  Westbrook  NBA  PG  80  80  36.4   9.5  21.1  ...  .737  1.9
# 61  2018-19  30  Westbrook  NBA  PG  73  73  36.0   8.6  20.2  ...  .656  1.5
# ...

# %%
stats_clean[stats_clean.Player=="Thompson"]
# Out:
#      Season Age    Player   Lg Pos   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 21  2011-12  21  Thompson  NBA  SG  66  29  24.4  4.8  10.9  ...  .868  0.4
# 22  2012-13  22  Thompson  NBA  SG  82  82  35.8  6.2  14.7  ...  .841  0.4
# 23  2013-14  23  Thompson  NBA  SG  81  81  35.4  6.9  15.5  ...  .795  0.5
# 24  2014-15  24  Thompson  NBA  SG  77  77  31.9  7.8  16.9  ...  .879  0.4
# 25  2015-16  25  Thompson  NBA  SG  80  80  33.3  8.1  17.3  ...  .873  0.4
# 26  2016-17  26  Thompson  NBA  SG  78  78  34.0  8.3  17.6  ...  .853  0.6
# 27  2017-18  27  Thompson  NBA  SG  73  73  34.3  7.9  16.2  ...  .837  0.4
# 28  2018-19  28  Thompson  NBA  SG  78  78  34.0  8.4  18.0  ...  .816  0.5
# 31  2021-22  31  Thompson  NBA  SG  32  32  29.4  7.7  17.9  ...  .902  0.5
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 21  2.1  2.4  2.0  0.7  0.3  1.6  2.3  12.5
# 22  3.3  3.7  2.2  1.0  0.5  1.9  2.9  16.6
# 23  2.6  3.1  2.2  0.9  0.5  1.7  2.9  18.4
# ...
